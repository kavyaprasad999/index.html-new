# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>

    <!-- The comment points are
        1. point 1
        2. point 2
        3. point 3
    -->

    <h1>This is h1 Heading</h1>

    <h2>This is h2 Heading</h2>

    <h3>This is h3 Heading</h3>

    <h3>This is h4 Heading</h3>

    <h5>This is h5 Heading</h5>

    <h6>This is h6 Heading</h6>

    <p id="123" class="c2 c3 c4">This is a <br> paragraph</p>
    <p>This is &nbsp; &nbsp; second paragraph</p>


    This is a normal text. <br>
    This is more normal.

    <hr>

    <ul type="none" id="uniqueid">
        <li class="c1"> list item 1</li>
        <li class="c2"> list item 2</li>
    </ul>

    <ol type="1" start="10" reversed="true">
        <li> list item 1</li>
        <li>list item 2</li>
    </ol>

    <ul type="1">
        <li> list item 1</li>
        <li> list item 2</li>
        <li>
            <ol>ABCD</ol>
            <ol>EFGH</ol>
        </li>
            <ul>
                someting
            </ul>

     </ul>

     <a href="https://www.google.com" target="-blank">Go to goole</a>

     <a href="https://www.yahoo.com" target="-blank">Go to yahoo</a>

     <div>
        Text in sub inner div <span style="border: 1px solid red;;"">I am inline</span>"
     </div>

     <h1 style="color: red; border: 1px solid red;;">Heading in inner div</h1> <span>I am inline</span>
     <h1>Heading in inner div</h1>

     <div>
        <p>
             Hello
        </p>
     </div>
     <a href="https://www.google.com" target="_blank">Go to goole</a>

     <div>
        some <b>bold text</b>

        some <strong>bold text</strong>

        some <i>italic text</i>

        some <mark>higlight text</mark>

        some <ins>underline text</ins>

        some <mark>highlite text</mark>

        <br>

        Formula -> E = mc <sup>2

            <br>

            Formula -> H <sub>2</sub>O

            <br>

            <del>strikethrough</del>

            <br>
            <br>

            This is a sentence with <small>smai</small> big <big>big</big>

            <br>
            <br>

            some <strong>bold text</strong>


        </sup>

     </div>

     <table border="1" cellpadding="10" cellspacring="10">
        <tr>


        </tr>

        <tr>
            <th>
                Name
            </th>
            <th>
                Age
            </th>
            <th>
                Address
            </th>
            <th>
                company

            </th>
        </tr>
        <tr>

            <td>
                One
            </td>
            <td>
                Two
            </td>
            <td>
                Three
            </td>
            <td>
                Four
            </td>




            <br>

            <tr>

            <td rowspan="2">
                One
            </td>
            <td>
                Two
            </td>
            <td>
                Three
            </td>
            <td>
                Four
            </td>

            </tr>


            <td>
                One
            </td>
            <td colspan="3" bgcolor="green">
                Two
            </td>
            ,
            <td>
                20
            </td>
            <tr>


            </tr>


        </tr>
     </table>

     <br>

     <div></div>
        <span>about</span>
        <span>contact us</span>
        <span>About us</span>
        <span>careers</span>
        <span>flipcart</span>
        <span>press</span>
     </div>

     <div>
        <span>Help</span>
        <span>Payment</span>
        <span>shipping</span>
        <span>cancelation</span>
     </div>

</body>
</html>
